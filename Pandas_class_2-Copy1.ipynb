# %%
import pandas as pd

# %% [markdown]
# # Create Dataframes

# %% [markdown]
# ## 1. load the file

# %%
# laoding the csv file
df = pd.read_csv('datasets/ted_data.csv')

# %%
df
# Out:
#           name_speaker                           speaker_occupation  \
# 0         Ken Robinson                              Author/educator
# 1              Al Gore                             Climate advocate
# 2          David Pogue                         Technology columnist
# 3        Majora Carter           Activist for environmental justice
# 4         Hans Rosling         Global health expert; data visionary
# 5         Tony Robbins  Life coach; expert in leadership psychology
# 6        Julia Sweeney                  Actor, comedian, playwright
# 7  Joshua Prince-Ramus                                    Architect
# 8          Dan Dennett             Philosopher, cognitive scientist
# 9          Rick Warren                               Pastor, author
#
#                                                title     views  comments
# 0                        Do schools kill creativity?  47227110      4553
# 1                        Averting the climate crisis   3200520       265
# ...

# %%
df.shape
# Out:
# (10, 5)

# %%
# loading a excel file
df = pd.read_excel('datasets/football_worldcup.xlsx')

# %%
df
# Out:
#    Year       Country    Winner   Runners-Up  GoalsScored  MatchesPlayed
# 0  1990         Italy  Germany     Argentina          115             52
# 1  1994           USA    Brazil        Italy          141             52
# 2  1998        France    France       Brazil          171             64
# 3  2002         Japan    Brazil      Germany          161             64
# 4  2006       Germany     Italy       France          147             64
# 5  2010  South Africa     Spain  Netherlands          145             64
# 6  2014        Brazil   Germany    Argentina          171             64

# %%
df.shape
# Out:
# (7, 6)

# %% [markdown]
# ## 2.  using dic

# %%
df_dict = {
    'Year' : [1990 , 1994 , 1995 , 2002],
    'Country' : ['abc' , 'xyz' , 'fgh' , 'tyu'],
    'Winner' : ['germany' , 'brazil' , 'france' , 'brazil'],
    'Goal_scored' : [115 , 141 , 171 , 161],
}

# %%
df_fifa = pd.DataFrame(df_dict)
df_fifa
# Out:
#    Year Country   Winner  Goal_scored
# 0  1990     abc  germany          115
# 1  1994     xyz   brazil          141
# 2  1995     fgh   france          171
# 3  2002     tyu   brazil          161

# %% [markdown]
# ## 3. using pd.series

# %%
df_dict = {
    'Year' : pd.Series([1990 , 1994 , 1995 , 2002 , 2008]),
    'Winner' : pd.Series(['germany' , 'brazil' , 'france' , 'brazil'])
}

# %%
df_series = pd.DataFrame(df_dict)
df_series
# Out:
#    Year   Winner
# 0  1990  germany
# 1  1994   brazil
# 2  1995   france
# 3  2002   brazil
# 4  2008      NaN

# %% [markdown]
# ## 4. using list of tuples

# %%
dic_lotuples = [(2002 , 'japan' , 'Brazil'),
               (2006 , ' Germnay' , 'Italy')]

# %%
df = pd.DataFrame(dic_lotuples , columns=pd.Series(["year" , "country" , "hosted_country"]))

# %%
df
# Out:
#    year   country hosted_country
# 0  2002     japan         Brazil
# 1  2006   Germnay          Italy

# %% [markdown]
# ## 5. using list of dic

# %%
df_dic = [
    {'year':2002 , 'Hosted_country' :'Japan'},
    {'year':2002 , 'Hosted_country' :'Germany'},
    {'year':2005 , 'Hosted_country' :'india'},
    {'year':2006 , 'Hosted_country' :'uk' , 'Winner':'Germany'}
]

# %%
df = pd.DataFrame(df_dic)

# %%
df
# Out:
#    year Hosted_country   Winner
# 0  2002          Japan      NaN
# 1  2002        Germany      NaN
# 2  2005          india      NaN
# 3  2006             uk  Germany

# %% [markdown]
# # Addition and deletion

# %%
df_org = pd.read_csv('datasets/international_org.csv')

# %%
df_org
# Out:
#   Organization Name  Headquater
# 0               FAO        Rome
# 1               ICJ   The Hague
# 2               IMF  Washington
# 3            UNESCO       Paris
# 4               UNO    New York
# 5        World Bank  Washington

# %% [markdown]
# ## adding a new column in dataframe

# %%
# creating a column and setting thevalue as default to all the rows
df_org['xyz'] = [1956 , 6,7,8,9,0]
df_org
# Out:
#   Organization Name  Headquater   xyz   abc
# 0               FAO        Rome  1956  1945
# 1               ICJ   The Hague     6     1
# 2               IMF  Washington     7     2
# 3            UNESCO       Paris     8     3
# 4               UNO    New York     9     4
# 5        World Bank  Washington     0     5

# %%
df_org['abC'] = [1947 , 1,2,3,4, None]
df_org
# Out:
#   Organization Name  Headquater   xyz   abc   abz  AVSGDUF   ABZ     abC
# 0               FAO        Rome  1956  1947  1947     1947  1947  1947.0
# 1               ICJ   The Hague     6     1     1        1     1     1.0
# 2               IMF  Washington     7     2     2        2     2     2.0
# 3            UNESCO       Paris     8     3     3        3     3     3.0
# 4               UNO    New York     9     4     4        4     4     4.0
# 5        World Bank  Washington     0     5     5        5     5     NaN

# %%
imdb_rating = pd.read_csv('datasets/imdb_rating.csv')

# %%
imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
# updating a value for a particular column
imdb_rating['duration'] = 44
imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0        44
# 1        44
# 2        44
# 3        44
# 4        44
# 5        44
# 6        44
# 7        44
# 8        44
# 9        44

# %%
# updating a paticular row of a particular column
imdb_rating['duration'][4] = 'Action'
# Out:
# <ipython-input-144-088f58e1e5f9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_rating['duration'][4] = 'Action'
# /root/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#   duration
# 0       44
# 1       44
# 2       44
# 3       44
# 4   Action
# 5       44
# 6       44
# 7       44
# 8       44
# 9       44

# %%
## Delete the column

# %%
del imdb_rating['duration']

# %%
type(imdb_rating['genre'])
# Out:
# pandas.core.series.Series

# %%
type(imdb_rating)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Adding a Row
#
# loc() function

# %%
imdb_rating.loc[1]
# Out:
# star_rating              9.2
# title          The Godfather
# genre                  Crime
# Name: 1, dtype: object

# %%
imdb_rating.loc[] = [10 , 'The Godfather 2' , 'action']
# Out:
#   File "<ipython-input-151-c47dd6c54be2>", line 1
#     imdb_rating.loc[] = [10 , 'The Godfather 2' , 'action']
#                     ^
# SyntaxError: invalid syntax

# %%
imdb_rating.loc[list(imdb_rating['star_rating']).index(10)]
# Out:
# star_rating                 10
# title          The Godfather 2
# genre                   action
# Name: 1, dtype: object

# %%
list(imdb_rating['star_rating']).index(8.9)
# Out:
# 4

# %%
imdb_rating['star_rating'][3] = 15
imdb_rating
# Out:
# <ipython-input-100-c872f8651db7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_rating['star_rating'][3] = 15
#     star_rating                                          title      genre
# 0           9.3                       The Shawshank Redemption      Crime
# 1          10.0                                The Godfather 2     action
# 2           9.1                         The Godfather: Part II      Crime
# 3          15.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction     Action
# 5           8.9                                   12 Angry Men     Action
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# ...

# %%
imdb_rating.loc[-1] = [10 , 'The Godfather 2' , 'action']
imdb_rating
# Out:
#     star_rating                                          title      genre
#  0          9.3                       The Shawshank Redemption      Crime
#  1          9.2                                  The Godfather      Crime
#  2          9.1                         The Godfather: Part II      Crime
#  3          9.0                                The Dark Knight     Action
#  4          8.9                                   Pulp Fiction      Crime
#  5          8.9                                   12 Angry Men      Drama
#  6          8.9                 The Good, the Bad and the Ugly    Western
#  7          8.9  The Lord of the Rings: The Return of the King  Adventure
#  8          8.9                               Schindler's List  Biography
#  9          8.9                                     Fight Club      Drama
# -1         10.0                                The Godfather 2     action

# %%
imdb_rating.sort_index()
# Out:
#     star_rating                                          title      genre
# -1         10.0                                The Godfather 2     action
#  0          9.3                       The Shawshank Redemption      Crime
#  1          9.2                                  The Godfather      Crime
#  2          9.1                         The Godfather: Part II      Crime
#  3          9.0                                The Dark Knight     Action
#  4          8.9                                   Pulp Fiction      Crime
#  5          8.9                                   12 Angry Men      Drama
#  6          8.9                 The Good, the Bad and the Ugly    Western
#  7          8.9  The Lord of the Rings: The Return of the King  Adventure
#  8          8.9                               Schindler's List  Biography
#  9          8.9                                     Fight Club      Drama

# %%
imdb_rating.index = imdb_rating.index + 1
imdb_rating.sort_index()
# Out:
#     star_rating                                          title      genre
# 5          10.0                                The Godfather 2     action
# 6           9.3                       The Shawshank Redemption      Crime
# 7           9.2                                  The Godfather      Crime
# 8           9.1                         The Godfather: Part II      Crime
# 9           9.0                                The Dark Knight     Action
# 10          8.9                                   Pulp Fiction      Crime
# 11          8.9                                   12 Angry Men      Drama
# 12          8.9                 The Good, the Bad and the Ugly    Western
# 13          8.9  The Lord of the Rings: The Return of the King  Adventure
# 14          8.9                               Schindler's List  Biography
# 15          8.9                                     Fight Club      Drama

# %%
imdb_rating[imdb_rating['star_rating'] == 8.9]
# Out:
#    star_rating                                          title      genre
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama

# %%
imdb_rating[-1] =
# Out:
#    star_rating                                          title      genre
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama

# %%
imdb_rating.sort_values('genre')
# Out:
#     star_rating                                          title      genre
# 5           9.0                                The Dark Knight     Action
# 9           8.9  The Lord of the Rings: The Return of the King  Adventure
# 10          8.9                               Schindler's List  Biography
# 2           9.3                       The Shawshank Redemption      Crime
# 3           9.2                                  The Godfather      Crime
# 4           9.1                         The Godfather: Part II      Crime
# 6           8.9                                   Pulp Fiction      Crime
# 7           8.9                                   12 Angry Men      Drama
# 11          8.9                                     Fight Club      Drama
# 8           8.9                 The Good, the Bad and the Ugly    Western
# 1          10.0                                The Godfather 2     action

# %%
#Q1 . update the title of the movi whoes rating is max
imdb_rating = pd.read_csv('datasets/imdb_rating.csv')

# %%
imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
imdb_rating.at[list(imdb_rating['star_rating']).index(max(list(imdb_rating['star_rating']))) , 'title'] = 'yup'

# %%
imdb_rating.at[max(imdb_rating['star_rating']),'title']='xyz'

# %%
b  = imdb_rating.sort_values('star_rating')

# %%
b
# Out:
#    star_rating                                          title      genre  \
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
# 3          9.0                                The Dark Knight     Action
# 2          9.1                         The Godfather: Part II      Crime
# 1          9.2                                  The Godfather      Crime
# 0          9.3                                            yup      Crime
#
#    duration
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139
# 3       152
# 2       200
# 1       175
# 0       142

# %%
a = b.reset_index()

# %%
b
# Out:
#    star_rating                                          title      genre  \
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
# 3          9.0                                The Dark Knight     Action
# 2          9.1                         The Godfather: Part II      Crime
# 1          9.2                                  The Godfather      Crime
# 0          9.3                                            yup      Crime
#
#    duration
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139
# 3       152
# 2       200
# 1       175
# 0       142

# %%
a
# Out:
#    index  star_rating                                          title  \
# 0      4          8.9                                   Pulp Fiction
# 1      5          8.9                                   12 Angry Men
# 2      6          8.9                 The Good, the Bad and the Ugly
# 3      7          8.9  The Lord of the Rings: The Return of the King
# 4      8          8.9                               Schindler's List
# 5      9          8.9                                     Fight Club
# 6      3          9.0                                The Dark Knight
# 7      2          9.1                         The Godfather: Part II
# 8      1          9.2                                  The Godfather
# 9      0          9.3                                            yup
#
#        genre  duration
# 0      Crime       154
# 1      Drama        96
# 2    Western       161
# 3  Adventure       201
# 4  Biography       195
# 5      Drama       139
# 6     Action       152
# ...

# %%
b
# Out:
#    star_rating                                          title      genre  \
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
# 3          9.0                                The Dark Knight     Action
# 2          9.1                         The Godfather: Part II      Crime
# 1          9.2                                  The Godfather      Crime
# 0          9.3                                            yup      Crime
#
#    duration
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139
# 3       152
# 2       200
# 1       175
# 0       142

# %% [markdown]
# #### delting using the drop function
#
# -- drop function will alwasy create a new dataframe

# %%
# row
imdb_rating = pd.read_csv('datasets/imdb_rating.csv')

# %%
imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
a = imdb_rating.drop(imdb_rating.index[[1]])

# %%
imdb_rating
# Out:
#    star_rating                           title      genre  duration
# 1          9.2                   The Godfather      Crime       175
# 2          9.1          The Godfather: Part II      Crime       200
# 3          9.0                 The Dark Knight     Action       152
# 5          8.9                    12 Angry Men      Drama        96
# 6          8.9  The Good, the Bad and the Ugly    Western       161
# 8          8.9                Schindler's List  Biography       195
# 9          8.9                      Fight Club      Drama       139

# %%
a
# Out:
#    star_rating                           title      genre  duration
# 1          9.2                   The Godfather      Crime       175
# 3          9.0                 The Dark Knight     Action       152
# 5          8.9                    12 Angry Men      Drama        96
# 6          8.9  The Good, the Bad and the Ugly    Western       161
# 8          8.9                Schindler's List  Biography       195
# 9          8.9                      Fight Club      Drama       139

# %%
imdb_rating.drop(columns=['genre' , 'duration'] , inplace=True)

# %%
imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
imdb_rating[imdb_rating['star_rating'] > 9.1]
# Out:
#    star_rating                     title  genre  duration
# 0          9.3  The Shawshank Redemption  Crime       142
# 1          9.2             The Godfather  Crime       175
