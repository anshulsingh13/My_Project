# %%
# Define a function calls addNumber(x, y) that takes in two number and returns the sum of the two numbers.

s=0
def addNumber(x, y):
    return x +  y
    

a = int(input("Enter first no:"))
b = int(input("Enter second no:"))
print("sum is:",addNumber(a,b))
# Out:
# Enter first no:10
# Enter second no:20
# sum is: 30

# %%
# Define a function calls subtractNumber(x, y) that takes in two numbers and returns the difference of the two numbers.


def subtractNumber(x, y):
    if x>y:
        return x -  y
    else:
        return y - x

a = int(input("Enter first no:"))
b = int(input("Enter second no:"))
print("difference is:",subtractNumber(a,b))
# Out:
# Enter first no:10
# Enter second no:20
# difference is: 10

# %%
# Write a function getBiggerNumber(x, y) that takes in two numbers as arguments and returns the bigger number.

def getBiggerNumber(x, y):
    if x>y:
        return x
    else:
        return y 

a = int(input("Enter first no:"))
b = int(input("Enter second no:"))
print("bigger no is:",getBiggerNumber(a,b))
# Out:
# Enter first no:10
# Enter second no:20
# bigger no is: 20

# %%
# Python provides many built-in modules with many useful functions. 
# One such module is the math module. The math module provides many useful functions such as sqrt(x), pow(x, y), ceil(x), floor(x) etc. 
# You will need to do a "import math" before you are allowed to use the functions within the math module.

import math as ma
# Calculate the square root of 16 and stores it in the variable a
a = ma.sqrt(16)
print(a)
# Calculate 3 to the power of 5 and stores it in the variable b
b = ma.pow(3,5)
print(b)
# Calculate area of circle with radius = 3.0 by making use of the math.pi constant and store it in the variable c
area = ma.pi*3*3
print(area)
# Out:
# 4.0
# 243.0
# 28.274333882308138

# %%
# Write a function to convert temperature from Celsius to Fahrenheit scale.
# oC to oF Conversion: Multipy by 9, then divide by 5, then add 32.

# Note: Return a string of 2 decimal places.
# In - Cel2Fah(28.0)
# Out - '82.40'
# In - Cel2Fah(0.00)
# Out - '32.00'

def convert(a):
    s = (a*9)/5+32
    print('%.2f'%s)
a = float(input("Enter temp in celsius:"))
convert(a)
# Out:
# Enter temp in celsius:0.00
# 32.00

# %%
# Write a function to compute the BMI of a person.
#     BMI = weight(kg)  /  ( height(m)*height(m) )

# Note: Return a string of 1 decimal place.
# In - BMI(63, 1.7)
# Out - '21.8'
# In - BMI(110, 2)
# Out - '27.5'

def convert(a,b):
    BMI = a/( b*b)
    print('%.1f'%BMI)
weight = float(input("Enter weight in kg:"))
height = float(input("Enter height in m:"))
convert(weight,height)
# Out:
# Enter weight in kg:63
# Enter height in m:1.7
# 21.8

# %%
# Write a function percent(value, total) that takes in two numbers as arguments, and returns the percentage value as an integer.
# In - percent(46, 90)
# Out - 51
# In - percent(51, 51)
# Out - 100
# In - percent(63, 12)
# Out - 525

def percent(x, y):
    return int(x/y*100)

a = int(input("Enter first no:"))
b = int(input("Enter second no:"))
print("Percent value is:",percent(a,b))
# Out:
# Enter first no:51
# Enter second no:51
# Percent value is: 100

# %%
# Write a function to compute the hypotenuse given sides a and b of the triangle.
# Hint: You can use math.sqrt(x) to compute the square root of x.
# In - hypotenuse(3, 4)
# Out - 5
# In - hypotenuse(5, 12)
# Out - 13

import math as ma
def hypotenuse(x, y):
    h = ma.pow(x,2) + ma.pow(y,2)
    return int(ma.sqrt(h))
a = int(input("Enter first no:"))
b = int(input("Enter second no:"))
print(f"hypotenuse of triangle with sides {a},{b} is:",hypotenuse(a,b))
# Out:
# Enter first no:3
# Enter second no:4
# hypotenuse of triangle with sides 3,4 is: 5

# %%
# Write a function getSumOfLastDigits() that takes in a list of positive numbers and returns the sum of all the last digits in the list.
# getSumOfLastDigits([2, 3, 4])
# 9
# getSumOfLastDigits([1, 23, 456])
# 10

def getSumOfLastDigits(l1):
    s = 0
    for i in range(3):
        l1 = lst1[i]%10
        s = s+l1
    return s

lst1 = [2, 3, 4]
print("Sum of last digits is:", getSumOfLastDigits(lst1))
lst1 = [1, 23, 456]
print("Sum of last digits is:", getSumOfLastDigits(lst1))
# Out:
# Sum of last digits is: 9
# Sum of last digits is: 10

# %%
# Write a function that uses a default value.
# In - introduce('Lim', 20)
# Out - 'My name is Lim. I am 20 years old.'
# In - introduce('Ahmad')
# Out - 'My name is Ahmad. My age is secret.'


def introduce(name, age  = 'secret'):
    if age =='secret':
        print(f"My name is {name}. My age is {age}")
    else:
        print(f"My name is {name}. I am {age} years old")

introduce('Lim',20)
introduce('Ahmad',)
# Out:
# My name is Lim. I am 20 years old
# My name is Ahmad. My age is secret

# %%
# Write a function isEquilateral(x, y, z) that accepts the 3 sides of a triangle as arguments. 
# The program should return True if it is an equilateral triangle.

# In - isEquilateral(2, 4, 3)
# False - False
# In - isEquilateral(3, 3, 3)
# Out - True
# In - isEquilateral(-3, -3, -3)
# Out - False

def isEquilateral(a,b,c):
    if a==b and b==c:
        print('True')
    else:
        print('Flase')

isEquilateral(2, 4, 3)  
isEquilateral(3, 3, 3)
isEquilateral(-3, -3, -3)
# Out:
# Flase
# True
# True

# %%
# For a quadratic equation in the form of ax2+bx+c, the discriminant, D is b2-4ac. Write a function to compute the discriminant, D.
# In - quadratic(1, 2, 3)
# Out - 'The discriminant is -8.'
# In - quadratic(1, 3, 2)
# Out - 'The discriminant is 1.'
# In - quadratic(1, 4, 4)
# Out - 'The discriminant is 0.'

import math as ma
def quadratic(a,b,c):
    d = ma.pow(b,2) - 4*a*c
    print("The discriminant is: ",int(d))

quadratic(1, 2, 3)
quadratic(1, 3, 2)
quadratic(1, 4, 4)
# Out:
# The discriminant is:  -8
# The discriminant is:  1
# The discriminant is:  0

# %%
# Define a function calls addFirstAndLast(x) that takes in a list of numbers and returns the sum of the first and last numbers.
# In - addFirstAndLast([])
# Out - 0
# In - addFirstAndLast([2, 7, 3])
# Out - 5
# In - addFirstAndLast([10])
# Out - 10

def addFirstAndLast(lst):
  if len(lst) == 1:
    print(lst[0])
  elif lst:
    print(lst[0] + lst[-1])
  else:
    print('List is empty')

addFirstAndLast([2,7,3])
addFirstAndLast([10])
addFirstAndLast([])
# Out:
# 5
# 10
# List is empty

# %%
# Complete the 'lambda' expression so that it returns True if the argument is an even number, and False otherwise.

(lambda num : True if num%2 == 0 else False)(1)
# Out:
# False

# %%
# getScore.__doc__
# 'A function that computes and returns the final score.'

def getScore():
  ''''A function that computes and returns the final score.'''
  pass
getScore.__doc__
# Out:
# "'A function that computes and returns the final score."

# %%
# In Python, it is possible to pass a function as a argument to another function. 
# Write a function useFunction(func, num) that takes in a function and a number as arguments. 
# The useFunction should produce the output shown in the examples given below.

# def addOne(x):
#   return x + 1
# useFunction(addOne, 4)
# 25
# useFunction(addOne, 9)
# 100
# useFunction(addOne, 0)
# 1


def addOne(x):
  return x + 1

def useFunction(addOne, n):
  print(addOne(n)**2)

useFunction(addOne, 4)
# Out:
# 25

# %%
def f1():
  print('This is f1 function')
  f1()
f1()
# Out:
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# This is f1 function
# ...

# %%
print('\\t')
# Out:
# \t
