# %% [markdown]
# # pandas basic functions

# %%
#import the lib
import pandas as pd

# %%
# read a csv file
data = pd.read_csv('datasets/weather_data.csv')

# %%
data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#shape
data.shape
# Out:
# (6, 4)

# %%
# tuple unpacking
a , b = data.shape
print(a , b)
# Out:
# 6 4

# %%
# head -- to print the top rows --- default value is 5
data.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
data.head(2)
# Out:
# day            object
# temperature     int64
# windspeed       int64
# event          object
# dtype: object

# %%
# tail - to print the bottom rows - default value willbe 5

data.tail(3)
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#slicing
data[3:5]
# Out:
#         day  temperature  windspeed event
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
# columns
data.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
data['day']

#or

data.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
data['windspeed']

# or

data.windspeed
# Out:
# 0    6
# 1    7
# 2    2
# 3    7
# 4    4
# 5    2
# Name: windspeed, dtype: int64

# %%
# extract two columns
data[['day' , 'windspeed']]
# Out:
#         day  windspeed
# 0  1/1/2017          6
# 1  1/2/2017          7
# 2  1/3/2017          2
# 3  1/4/2017          7
# 4  1/5/2017          4
# 5  1/6/2017          2

# %%
#max
data.max()['temperature']
# Out:
# 35

# %%
data.temperature.max()
# Out:
# 35

# %%
# min
data.min()
# Out:
# day            1/1/2017
# temperature          24
# windspeed             2
# event              Rain
# dtype: object

# %%
# mean
data.mean()
# Out:
# temperature    30.333333
# windspeed       4.666667
# dtype: float64

# %%
data.median()
# Out:
# temperature    31.5
# windspeed       5.0
# dtype: float64

# %%
# 5 3 2 8 10

# # sort the value in ascending order

# 2 3 5 8 10 11

# # spot the middle value

# median is 5 + 8 / 2

# %%
data.dtypes
# Out:
# day            object
# temperature     int64
# windspeed       int64
# event          object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
data[['event' , 'temperature']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   event        6 non-null      object
#  1   temperature  6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
# how to convert the tring into date time format
pd.to_datetime(data.day)
# Out:
# 0   2017-01-01
# 1   2017-01-02
# 2   2017-01-03
# 3   2017-01-04
# 4   2017-01-05
# 5   2017-01-06
# Name: day, dtype: datetime64[ns]

# %%
data.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
data['days'] = data.day

# %%
data
# Out:
#          day  temperature  windspeed  event       days
# 0 2017-01-01           32          6   Rain 2017-01-01
# 1 2017-01-02           35          7  Sunny 2017-01-02
# 2 2017-01-03           28          2   Snow 2017-01-03
# 3 2017-01-04           24          7   Snow 2017-01-04
# 4 2017-01-05           32          4   Rain 2017-01-05
# 5 2017-01-06           31          2  Sunny 2017-01-06

# %%
data.dtypes
# Out:
# day            datetime64[ns]
# temperature             int64
# windspeed               int64
# event                  object
# days           datetime64[ns]
# dtype: object

# %%
# basic stats of the dataset
data.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
data.describe(include = 'all')
# Out:
# <ipython-input-56-2258166cf291>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include = 'all')
# <ipython-input-56-2258166cf291>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include = 'all')
#                         day  temperature  windspeed event                 days
# count                     6     6.000000   6.000000     6                    6
# unique                    6          NaN        NaN     3                    6
# top     2017-01-05 00:00:00          NaN        NaN  Snow  2017-01-05 00:00:00
# ...

# %%
data['temp'] = pd.Categorical(data.temperature)

# %%
data.describe(include = 'all')
# Out:
# <ipython-input-58-2258166cf291>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include = 'all')
# <ipython-input-58-2258166cf291>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include = 'all')
#                         day  temperature  windspeed event  \
# count                     6     6.000000   6.000000     6
# unique                    6          NaN        NaN     3
# top     2017-01-05 00:00:00          NaN        NaN  Snow
# freq                      1          NaN        NaN     2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      datetime64[ns]
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
#  4   days         6 non-null      datetime64[ns]
#  5   temp         6 non-null      category
# dtypes: category(1), datetime64[ns](2), int64(2), object(1)
# memory usage: 574.0+ bytes

# %%
data.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
# slicing and indexing
bike_df = pd.read_csv('datasets/citibike_tripdata.csv')

# %%
bike_df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  object
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 2.5+ MB

# %%
bike_df.describe(include = 'all')
# Out:
#          tripduration            starttime             stoptime  \
# count    32428.000000                32428                32428
# unique            NaN                31859                31899
# top               NaN  2018-05-11 21:36:28  2018-05-25 09:10:30
# freq              NaN                    3                    3
# mean       798.978352                  NaN                  NaN
# std       9961.203954                  NaN                  NaN
# min         61.000000                  NaN                  NaN
# 25%        236.000000                  NaN                  NaN
# 50%        352.000000                  NaN                  NaN
# 75%        590.000000                  NaN                  NaN
# max     936970.000000                  NaN                  NaN
#
#         start station id start station name  end station id end station name  \
# count       32428.000000              32428    32428.000000            32428
# ...

# %%
bike_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
bike_df.tail(30)
# Out:
#        tripduration            starttime             stoptime  \
# 32398           276  2018-05-30 13:18:03  2018-05-30 13:22:40
# 32399           368  2018-05-30 13:18:01  2018-05-30 13:24:10
# 32400           314  2018-05-30 13:18:05  2018-05-30 13:23:19
# 32401           225  2018-05-30 13:18:06  2018-05-30 13:21:52
# 32402           362  2018-05-30 13:18:16  2018-05-30 13:24:19
# 32403           485  2018-05-30 13:20:10  2018-05-30 13:28:16
# 32404           419  2018-05-30 13:20:50  2018-05-30 13:27:50
# 32405           326  2018-05-30 13:22:03  2018-05-30 13:27:29
# 32406           302  2018-05-30 13:22:50  2018-05-30 13:27:52
# 32407           280  2018-05-30 13:23:05  2018-05-30 13:27:45
# 32408           152  2018-05-30 13:24:24  2018-05-30 13:26:57
# 32409           560  2018-05-30 13:25:16  2018-05-30 13:34:37
# 32410           306  2018-05-30 13:29:58  2018-05-30 13:35:05
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# ...

# %%
bike_df[['tripduration' , 'stoptime']].head()
# Out:
#    tripduration             stoptime
# 0           338  2018-05-01 00:10:25
# 1          1482  2018-05-01 01:55:53
# 2           232  2018-05-01 01:35:22
# 3           190  2018-05-01 02:06:40
# 4           303  2018-05-01 04:32:16

# %%
bike_df[['tripduration' , 'stoptime']].tail()
# Out:
#        tripduration             stoptime
# 32423           396  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:55:08
# 32426          1130  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:57:08

# %%
# at function is ued to find the value between intersection of rows and column
bike_df.at[32423 , 'stoptime'] = 'abc'

# %%
bike_df[['tripduration' , 'stoptime']].tail()
# Out:
#        tripduration             stoptime
# 32423           396                  abc
# 32424           313  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:55:08
# 32426          1130  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:57:08

# %%
# for tripduration give me the value present at row 32400 and chnag the value to 341
bike_df.at[32400 , 'tripduration'] = 341

# %%
bike_df.tail(30)
# Out:
#        tripduration            starttime             stoptime  \
# 32398           276  2018-05-30 13:18:03  2018-05-30 13:22:40
# 32399           368  2018-05-30 13:18:01  2018-05-30 13:24:10
# 32400           341  2018-05-30 13:18:05  2018-05-30 13:23:19
# 32401           225  2018-05-30 13:18:06  2018-05-30 13:21:52
# 32402           362  2018-05-30 13:18:16  2018-05-30 13:24:19
# 32403           485  2018-05-30 13:20:10  2018-05-30 13:28:16
# 32404           419  2018-05-30 13:20:50  2018-05-30 13:27:50
# 32405           326  2018-05-30 13:22:03  2018-05-30 13:27:29
# 32406           302  2018-05-30 13:22:50  2018-05-30 13:27:52
# 32407           280  2018-05-30 13:23:05  2018-05-30 13:27:45
# 32408           152  2018-05-30 13:24:24  2018-05-30 13:26:57
# 32409           560  2018-05-30 13:25:16  2018-05-30 13:34:37
# 32410           306  2018-05-30 13:29:58  2018-05-30 13:35:05
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# ...

# %%
bike_df.at[bike_df.max.['tripduration'], 'tripduration'] = 0
# Out:
#   File "<ipython-input-79-f40597c4649a>", line 1
#     bike_df.at[bike_df.max.['tripduration'], 'tripduration'] = 0
#                            ^
# SyntaxError: invalid syntax

# %%
list(bike_df[bike_df['tripduration'] == max(bike_df['tripduration'])].index)
# Out:
# [24719]

# %%
bike_df = pd.read_csv('datasets/citibike_tripdata.csv')

# %%
list(bike_df[bike_df['tripduration'] == max(bike_df['tripduration'])].index)
# Out:
# [10873]

# %%
bike_df.at[list(bike_df[bike_df['tripduration'] == max(bike_df['tripduration'])].index), 'tripduration'] = 0

# %%
bike_df[bike_df['tripduration'] == 0]
# Out:
#        tripduration            starttime             stoptime  \
# 10873             0  2018-05-09 20:04:32  2018-05-20 16:20:42
#
#        start station id start station name  end station id  end station name  \
# 10873              3638      Washington St            3198  Heights Elevator
#
#        bikeid name_localizedValue  usertype
# 10873   26210             24 Hour  Customer

# %%
list(bike_df['tripduration']).index(max(list(bike_df['tripduration'])))
# Out:
# 10873

# %%
#slicing
new_bike = bike_df[:6]
new_bike
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
# ...

# %%
idx = ['row1' , 'row2' ,'row3' ,'row24' ,'row25' ,'row26']

# %%
new_bike.index = idx

# %%
new_bike
# Out:
#        tripduration            starttime             stoptime  \
# row1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row24           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row25           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row26           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row1               3639         Harborside            3199     Newport Pkwy
# row2               3681           Grand St            3185        City Hall
# row3               3194    McGinley Square            3193     Lincoln Park
# row24              3185          City Hall            3186    Grove St PATH
# row25              3207        Oakland Ave            3195          Sip Ave
# ...

# %%
new_bike.loc['row25']
# Out:
# tripduration                           303
# starttime              2018-05-01 04:27:12
# stoptime               2018-05-01 04:32:16
# start station id                      3207
# start station name             Oakland Ave
# end station id                        3195
# end station name                   Sip Ave
# bikeid                               15271
# name_localizedValue      Annual Membership
# usertype                        Subscriber
# Name: row25, dtype: object

# %%
new_bike.loc[:'row25']
# Out:
#        tripduration            starttime             stoptime  \
# row1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row24           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row25           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row1               3639         Harborside            3199     Newport Pkwy
# row2               3681           Grand St            3185        City Hall
# row3               3194    McGinley Square            3193     Lincoln Park
# row24              3185          City Hall            3186    Grove St PATH
# row25              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row1    33558                        Annual Membership  Subscriber
# ...

# %%
new_bike.loc['row3':'row25']
# Out:
#        tripduration            starttime             stoptime  \
# row3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row24           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row25           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row3               3194    McGinley Square            3193     Lincoln Park
# row24              3185          City Hall            3186    Grove St PATH
# row25              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row3    29217  FREE Bonus Month with Annual Membership  Subscriber
# row24   29662                                  24 Hour    Customer
# row25   15271                        Annual Membership  Subscriber

# %%
new_bike.loc['row3':'row25' ,  : 'end station id']
# Out:
#        tripduration            starttime             stoptime  \
# row3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row24           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row25           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id
# row3               3194    McGinley Square            3193
# row24              3185          City Hall            3186
# row25              3207        Oakland Ave            3195

# %%
# give me all the rows where tripduration is more than 200 only for the columns bikeid user_type
new_bike.loc[new_bike['tripduration'] > 200]
# Out:
#        tripduration            starttime             stoptime  \
# row1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row25           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row1               3639         Harborside            3199     Newport Pkwy
# row2               3681           Grand St            3185        City Hall
# row3               3194    McGinley Square            3193     Lincoln Park
# row25              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row1    33558                        Annual Membership  Subscriber
# row2    33593                                  24 Hour    Customer
# row3    29217  FREE Bonus Month with Annual Membership  Subscriber
# ...

# %%
new_bike.loc[new_bike['tripduration'] > 200 , ['bikeid' , 'usertype']]
# Out:
#        bikeid    usertype
# row1    33558  Subscriber
# row2    33593    Customer
# row3    29217  Subscriber
# row25   15271  Subscriber

# %%
bike_df.iloc[1:3 , :8]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
#
#   start station name  end station id end station name  bikeid
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217

# %%
bike_df.iloc[[2,3,4] , :]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 2  FREE Bonus Month with Annual Membership  Subscriber
# 3                                  24 Hour    Customer
# 4                        Annual Membership  Subscriber

# %%
# display me only those data where usertype is Subscriber
bike_df[bike_df['usertype']=='Subscriber']
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 5               176  2018-05-01 04:37:05  2018-05-01 04:40:01
# 6               577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id     start station name  end station id  \
# 0                  3639             Harborside            3199
# 2                  3194        McGinley Square            3193
# ...

# %%
bike_df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
bike_df.iloc[7:10 , : ]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# 7            Oakland Ave            3185        City Hall   33624
# 8  Baldwin at Montgomery            3186    Grove St PATH   26300
# 9                Hilltop            3195          Sip Ave   33555
#
#          name_localizedValue    usertype
# 7          Annual Membership  Subscriber
# 8          Annual Membership  Subscriber
# 9  $25 Off Annual Membership  Subscriber

# %%
# display me only those data where usertype is Subscriber and bikeid is less than 30000
bike_df.loc[(bike_df.usertype == 'Subscriber')  (bike_df.bikeid <30000)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-5f2b6db73668> in <module>
#       1 # display me only those data where usertype is Subscriber and bikeid is less than 30000
# ----> 2 bike_df.loc[(bike_df.usertype == 'Subscriber') and (bike_df.bikeid <30000)]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
